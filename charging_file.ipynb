# %%
import pandas as pd

# %%
df = pd.read_excel("data.xlsx")

# %%
# total len
len(df)
# Out:
# 125

# %%
#unique
len(df["Primary Used by"].unique())
# Out:
# 120

# %%
# print duplicates 
df[df.duplicated(['Primary Used by'])]
# Out:
#        CI Name*                    Primary Used by Primary Used by Login  \
# 28  HC-UT50176N       Tuan Nguyen Thanh (HcP/FCM3)                GUU2HC
# 59     TEZZ1287        Florian Kogler (PS-EC/EFV5)                KFL5WI
# 64   PG1UT0365N  Eu Jin Benjamin Mah (CI/CWR31-AS)               MAE1PG1
# 65     SI-Z0W3X            Denis Haecker (PS/ETT4)                DEH1SI
# 91  HC-UT50476N         Binh Nguyen Duc (HcP/FCM3)                GIB1HC
#
#      RecCC
# 28  183200
# 59  941700
# 64  905903
# 65  209529
# 91  183200

# %%
df = df.dropna(how='any',axis=0)

# %%
# get unique details
df.drop_duplicates(['Primary Used by'], inplace= True)
print(len(df))
# Out:
# 119

# %%
df
# Out:
#           CI Name*                                  Primary Used by  \
# 0        BANZ65515            Ravi Shankar Kayampady (BT-IA/ASA-IN)
# 1         MLLZ0486                      Henrik Westman (CI/CER2-NE)
# 2       ML-UT0001C                  Ma. Luisa Faller (PT-BE/MKU-AP)
# 3         NU3Z1256                       Markus Jank (BT-VS/ETP1.1)
# 4         SI-Z0O2D                          Denis Haecker (PS/ETT4)
# 5         SI-Z0OO6                          Walter Knoedl (PS/ETT4)
# 6         BANZ1891                         D Kannan (BT-IA/SDP1-IN)
# 7         PCIZ0254                      Bogdan Cikusa (PciP/BPS-IE)
# 8    SGHZ001014123                            Ji ZHAO (PT-HG/SKA15)
# 9         BANZ2064                 Devika Banerjie (BT-CO/MKR1-SAI)
# 10      PG-UT5476N                Eu Jin Benjamin Mah (CI/CWR31-AS)
# 11        PCIZ0284                        Mile Mudric (PciP/BPS-IE)
# 12        PCIZ0288                    Nikola Knezevic (PciP/BPS-IE)
# 13        SABZ2041                                   Tobias Pirtsch
# 14        BANZ2752            EXTERNAL Pushkar Singh (BT-IA/SDP-in)
# 15     HC-UT50191C                     Tuan Nguyen Thanh (HcP/FCM3)
# 16        BANZ2882              Bhushan Karandikar (BT-CO/MKR2-SAI)
# 17        PCIZ0332                 Jelena Jakovljevic (PciP/BPS-IE)
# 18        BOXY1071               Lars van Roosmalen (DC-LP/PJM-Box)
# 19       CA1NB5249                    Raphael Trindade (BT/SLB-SDM)
# 20       JU-F8B43F                   Jorge Grado Cepeda (JuP1/FCM2)
# 21        BANZ3005           EXTERNAL Praveen S Naik (BT-IA/SDP-IN)
# 22        DEVY0079              Svenja Bielefeld (TT-RH/ENG1.1-Dev)
# 23        BANZ3036               Dipankar Sengupta (BT-CO/MKR2-SAI)
# 24        SABZ2077                                      Uwe Peppler
# 25       OWT8369EF                       Chuck Miklich (AA/MFG-Owt)
# 26       PT-T01244                       Estevao Silva (AE/MFI-CT5)
# 27       JU-EE6F87         Claudia Maribel Lopez Posadas (JuP1/HSE)
# 29        SI-Z0TNP                                      Thomas Lang
# 30       WI-Z11140                      Florian Kogler (PS-EC/EFV5)
# 31        BANZ3456                              H V Sridhar (C/AUT)
# 32       SGPZ72622                          Ronnie Lai (BT-CO/MKA1)
# 33       AD1909AC8                     John Boyd (PS/ENG2.23-ES-NA)
# 34       BUV98E08B                    Mike Reynolds (BT-CO/MKA1-NA)
# 35      JU3-C13385           Angel Abraham Alvarez Salas (JuP2/TEF)
# 36        FE-Z1EHR                       Ales Juergens (PS-EC/EHC4)
# 37       AD116041E                            Bill Hughes (AdP/FCM)
# 38        BANZ3412               Himanshu Bhardwaj (BT-CO/MKR2-SAI)
# 39     HC-UT40320N                       Tam Ngo Thanh (RBVH/ETM31)
# 40       OWTC14745            EXTERNAL Samual Stachel (AA/TEF1-Owt)
# 42       OWTC2B44A                       Matt Bartsch (AA/TEF1-Owt)
# 43       MTP07DD4D             EXTERNAL Caitlyn Miklasz (PT-RT/PXB)
# 44       OWT09D71F                       Scott Jirele (AA/TEF1-Owt)
# 45       CA1TC0308                       Eduardo Correa (AA/MBL-LA)
# 46        BRTZ0254                         Tomas Sotak (BT/SEP-SBV)
# 47        PCIZ0498                     Slaven Tosovic (PciP/BPS-IE)
# 48        PCIZ0501                                    Danny Bijnens
# 49       SLP37C39C  Angelica Gabriela Parrilla Espinosa (SlpP/FCM3)
# 50        DEVY00AH                Hennie Blanke (TT-RHW/EAP1.1-Dev)
# 51       BUV37C443                    Omar Palacios (BT-CO/MKA1-NA)
# 52       OWT3CCA35                  Wallace Hayenga (AA/MFG1.2-Owt)
# 53        BANZ4046                      S M Manohar (BT-IA/SDP1-IN)
# 54        LE-Z9383                           Peter Wolf (PT-MT/ETC)
# 55        SABZ2192                         Oliver Sahm (BT-CO/MKA1)
# 56       BP-F00470                      Andor Jager (PS-PE/ENG7-BP)
# 57       OWT759458                    Anthony Morelli (AA/TEF2-Owt)
# 58       JU-3AB339       Kevin Arturo Padilla Garcia (JuP1/PJM1.11)
# 60   SGHZ001025550                             Danni LI (NjP1/FCM1)
# 61        ER-Z2874                         Laura Babilon (DC/PJ-FA)
# 62       ATBNB0672                                   Marcos Cardozo
# 63       WH1000282                                    Thomas Driese
# 66        SI-Z0W4P                         Stefan Braeuer (PS/ETT4)
# 67       OWT188374                     Adam Kesselman (AA/TEF1-Owt)
# 68       HESDEE882                    Mikal Williams (DCNA/LOG-Hes)
# 69       FH1EFAB7B     Karthik Aranvoyal Loganathan (PS-EC/EBR1-NA)
# 70       JU-72BA46       Jacqueline Carrasco Arrieta (JuP1/PJM1.11)
# 71        WZ-N3709                Weronika Szczepanik (DCEE/ADM-PL)
# 72        BJ-Z4777                       David Kocar (RBCB/TEF13.1)
# 73        BU1Z5533                        Mesut Yilmaz (CI/CER2-TR)
# 74        MANZ4060                   Alper Attias (TT-RHW/EAP3-Man)
# 75        MANZ4061                        Burhan Erdal (CI/CER3-TR)
# 76     HC-UT50406C                       Binh Nguyen Duc (HcP/FCM3)
# 77        EH-Z6269                       Tobias Volkmar (EhP/PJ-ZE)
# 78       JU-D3A667     Ruben Eduardo Salcido Espinoza (JuP1/PJM1.1)
# 79       JU-D4965D     Irvin Eduardo Galvan Banderas (JuP1/PJM1.11)
# 80        SABZ2289                      Martin Lingk (BT/SAS-EU-DE)
# 81       BUVE2E041                 Robert Deyarmond (BT-CO/MKA1-NA)
# 82        PCIZ0675                  Andreja Kojanic (EDA-WS/PJ-NGL)
# 83        PCIZ0682                    Ivana Stankovic (PciP/BPS-IE)
# 84        ABTZ0KN0                         Alf Neustadt (CC-PS/ELY)
# 85        PCIZ0688                    Dragan Bomestar (PciP/BPS-IE)
# 86        PCIZ0738                    Milos Jakovljev (PciP/BPS-IE)
# 87        PCIZ0740                   Aleksa Ivanovic (PciP/MSE2-WS)
# 88        SI-Z0XGV                         Martin Hettwer (PS/ETT4)
# 89       SYV69E31A                    Thomas Rocznik (CR/RTC4.4-NA)
# 90       MISF1BF83                      Valentin Calu (CI/CWR12-WA)
# 92   SGHZ001029678                   Marc Patrick ZAPF (CR/RTC5-AP)
# 93        PCIZ0782                         Luka Vuletic (PciP/LOP2)
# 94        SI-Z0YB4                           Michael Roth (PS/ETT4)
# 95      KOR1113739                        Murali Vidhya (RBEI/ETM1)
# 96       LE-Z10309                       Tobias Zibold (PT-MT/PXP2)
# 97        EINY24I1                    Ruud Toonders (BT-VS/MKR5-EU)
# 98      PG1UT0565N                           Luis Nunes (AE/MFT1.5)
# 99       AD1B10DE2                       Jason Mosley (AdP/MOE4.51)
# 100      BA0Z15333                    Andre Hasselmann (BaP/TEF6.2)
# 101      JU-B128CC     Cristina Adilene Alarcon Barboza (JuP1/MFO7)
# 102  SGHZ001032934                         Jian PENG (ATMO-5CN/END)
# 103       WZ-N4130                      Michal Czapski (CI/CER4-CE)
# 104       LR-Z8583                     Matthias Buck (CC-DA/PJ-NLR)
# 105       BJ-Z5255                       Michal Suster (CI/CER2-CE)
# 106    EPA3-6CA593                      Julio Morales (GS/LOW-NA25)
# 107       BOXY10FN                     Erik Krebbeks (DC-LP/SVC121)
# 108     KOR1114748               Siva Chaitanya Sangada (RBEI/ETM1)
# 109      JU-211CBB          Jose Ignacio Ramirez Riojas (JuP1/FCM1)
# 110       ABTZ0MDN                         Mario Lietz (CC-PS/ELY1)
# 111       FE-Z1T17                     Arkadius Zuzel (ETAS/EAS-CM)
# 112      ITVNB1034                  Wendell Rodrigues (GS/LOW41-LA)
# 113     COB1121168                  Nagarajan Subashini (RBEI/BSA2)
# 114       EBHX03GU                        Mark Lueckoff (EbhP/TEF1)
# 115       DUBN0367                       Klaus Seitz (BT/SAS-EU-ME)
# 116      LE-Z11153                             Kai Renz (PT-MT/ETC)
# 117      LE-Z11154                       Stephan Rindle (PT-MT/ETC)
# 118       FE-Z1VPB                  Aleksandar Damjanac (PS/CTG-BA)
# 119    COB-C-0000T             Perumal Ramakrishnan (RBEI/ECD23-EC)
# 120     JH-C-000GJ                      Veronika Mandatova (FCM-Jh)
# 121      BRGZN0520                 Filipa Raimundo (CC-PS/ENG5-Brg)
# 122       LOLX0B68                            Luca Bopf (HOME/ENG1)
# 123    OWT-C-00002                        Scott Piper (AA/LOP2-Owt)
# 124    OWT-C-00003                      Charlie Royce (AA/TEF2-Owt)
#
#     Primary Used by Login       RecCC
# 0                 KRY1BAN      903S05
# 1                 WNH1MLL      SE6142
# 2                 FAL5MNL      564240
# 3                 JAM2NU3      375255
# 4                  DEH1SI      209529
# 5                WAKNOEDL      209529
# 6                 DKA1BAN      903S03
# 7                 CIB1PCI      287704
# 8                  ZAJ2HZ      667906
# 9                  DAN5ND      54F841
# 10                MAE1PG1      905903
# 11                MUM9PCI      287704
# 12                KNN9PCI      287704
# 13                PIT2SAB      154570
# 14                 SIP1ND      903S03
# 15                 GUU2HC      183200
# 16                KAB5BAN      54F847
# 17                JAJ1PCI      287704
# 18                VLN1BOX      NL3004
# 19                 TRR1CA      684159
# 20                 GDJ3JU      698272
# 21                NAP3BAN      903S04
# 22                 BSV7FE      372311
# 23                SED5KOL      54F847
# 24                PEU1SAB      154570
# 25                MHC1OWT      13C900
# 26                ESS9BRG      815192
# 27                 LOC3JU      698250
# 29                 THLANG      209529
# 30                 KFL5WI      941700
# 31                SRV7KOR      280773
# 32                ROL1SGP      062545
# 33                 JHB2AN      981540
# 34                REM1BUV      711399
# 35                ALA1JU2      05D016
# 36                 BRA2FE      295160
# 37                 HUB1AD      982427
# 38                 BHH4ND      54F847
# 39                 AGO1HC      38F062
# 40                TCS1OWT      13C900
# 42                BAM2OWT      13C900
# 43                MIC3MTP      511451
# 44                JIS1OWT      13C900
# 45                 COD5CA      684031
# 46                SKT1BRT      527920
# 47                TOS1PCI      287704
# 48                 BID2TI      287601
# 49                PAA4SLP      61B226
# 50                HBL0DEV      372307
# 51                PALACIO      711399
# 52                HAW1OWT      13C900
# 53                MOU7KOR      903S03
# 54                 WFP2LE      211512
# 55                SAO2SAB      154570
# 56                 JNG2BP      866958
# 57                MOA1OWT      13C900
# 58                 PAK2JU      698307
# 60                 LDA3NJ      586383
# 61                 BAL1ER      718940
# 62                 CAC9PO      BR1016
# 63                TDRZWZL      211919
# 66               STBRAEUE      209529
# 67                KAA1OWT      13C900
# 68                WMI1HES  US40144009
# 69                 LOK2FH      981661
# 70                 AJC1JU      698307
# 71                SZW1WZ1      PL1403
# 72                 DKO1BJ      506875
# 73                 YLM2BU      939140
# 74                 AAT2IZ      829510
# 75                 ERB4IZ      829620
# 76                 GIB1HC      183200
# 77                 VOO9EH      816830
# 78                 SRU3JU      698301
# 79                 GAI3JU      698307
# 80                LIM1SAB      154786
# 81                DDR1BUV      711399
# 82                 KOJ1BG      287922
# 83                STI1PCI      287704
# 84                NEL2ABT      201567
# 85                BOD9PCI      287704
# 86                JMI1PCI      287704
# 87                IVA1PCI      287601
# 88                 HET1SI      209529
# 89                RKT2PAL      980443
# 90                CAV1MIS      979860
# 92                ZAP2SGH      667270
# 93                VUL6PCI      287420
# 94                 OIM2SI      209529
# 95                VMA4KOR      652050
# 96                 ZIB2LE      211588
# 97                RTO5EIN      047561
# 98                LFN3BRG      18C955
# 99                 MYJ3AD      982314
# 100                HAA2BA      060874
# 101                LRR1JU      698396
# 102               PEJ4CNG      257720
# 103                CAM8WZ      865910
# 104                MBK1SI      201894
# 105                SUM8BJ      506803
# 106               MSJ1CG2      980220
# 107              ERIKKREB      NL1265
# 108               IGN7KOR      652050
# 109                RRJ3JU      698272
# 110               LMT2ABT      201567
# 111                ZUA9FE      537120
# 112               ROW5LOV      908777
# 113               SBN5COB      652W41
# 114               MLU9EBH      251151
# 115               SEK1DUB      170998
# 116                RZK2LE      211512
# 117                RIS3LE      211512
# 118                DAL4FE      213690
# 119               RPE7COB      652S41
# 120                MVE9JH      515650
# 121               FIR2BRG      815888
# 122               BOL8LOL      67C701
# 123               PRS1OWT      13C900
# 124               ROC1OWT      13C900

# %%
df1 = df.groupby(["RecCC"]).size().reset_index(name='counts')

# %%
df1.counts.sum()
# Out:
# '1.000001.000001.000001.000009.000003.000001.000001.000002.000001.000002.000001.000006.000003.000001.000001.000001.000001.000001.000001.000001.000002.000008.000001.000001.000001.000001.000001.000001.000001.000001.000001.000001.000001.000001.000001.000003.000001.000001.000001.000002.000001.000001.000001.000001.000001.000001.000001.000001.000002.000001.000003.000001.000003.000001.000001.000001.000001.000001.000001.000001.000001.000003.000001.000001.000001.000001.000001.000001.000001.000001.000001.000001.000001.000001.000001.000001.000001.000001.000001.000001.000001.00000'

# %%
list1 = list()
list2 = list()

# %%
for i in df1["RecCC"]:
    list1.append(i[:3])
    list2.append(i[3:])

# %%
df1["RecCC1"] = list1
df1["RecCC2"] = list2

# %%
pd.set_option("display.max_rows", 500)

# %%
counts = list()

# %%
for i in df1["counts"]:
    counts.append(str(i)+"0000")

# %%
df1["counts"] = counts

# %% [markdown]
# #

# %%
df1
# Out:
#          RecCC   counts RecCC1   RecCC2
# 0       047561  1.00000    047      561
# 1       05D016  1.00000    05D      016
# 2       060874  1.00000    060      874
# 3       062545  1.00000    062      545
# 4       13C900  9.00000    13C      900
# 5       154570  3.00000    154      570
# 6       154786  1.00000    154      786
# 7       170998  1.00000    170      998
# 8       183200  2.00000    183      200
# 9       18C955  1.00000    18C      955
# 10      201567  2.00000    201      567
# 11      201894  1.00000    201      894
# 12      209529  6.00000    209      529
# 13      211512  3.00000    211      512
# 14      211588  1.00000    211      588
# 15      211919  1.00000    211      919
# 16      213690  1.00000    213      690
# 17      251151  1.00000    251      151
# 18      257720  1.00000    257      720
# 19      280773  1.00000    280      773
# 20      287420  1.00000    287      420
# 21      287601  2.00000    287      601
# 22      287704  8.00000    287      704
# 23      287922  1.00000    287      922
# 24      295160  1.00000    295      160
# 25      372307  1.00000    372      307
# 26      372311  1.00000    372      311
# 27      375255  1.00000    375      255
# 28      38F062  1.00000    38F      062
# 29      506803  1.00000    506      803
# 30      506875  1.00000    506      875
# 31      511451  1.00000    511      451
# 32      515650  1.00000    515      650
# 33      527920  1.00000    527      920
# 34      537120  1.00000    537      120
# 35      54F841  1.00000    54F      841
# 36      54F847  3.00000    54F      847
# 37      564240  1.00000    564      240
# 38      586383  1.00000    586      383
# 39      61B226  1.00000    61B      226
# 40      652050  2.00000    652      050
# 41      652S41  1.00000    652      S41
# 42      652W41  1.00000    652      W41
# 43      667270  1.00000    667      270
# 44      667906  1.00000    667      906
# 45      67C701  1.00000    67C      701
# 46      684031  1.00000    684      031
# 47      684159  1.00000    684      159
# 48      698250  1.00000    698      250
# 49      698272  2.00000    698      272
# 50      698301  1.00000    698      301
# 51      698307  3.00000    698      307
# 52      698396  1.00000    698      396
# 53      711399  3.00000    711      399
# 54      718940  1.00000    718      940
# 55      815192  1.00000    815      192
# 56      815888  1.00000    815      888
# 57      816830  1.00000    816      830
# 58      829510  1.00000    829      510
# 59      829620  1.00000    829      620
# 60      865910  1.00000    865      910
# 61      866958  1.00000    866      958
# 62      903S03  3.00000    903      S03
# 63      903S04  1.00000    903      S04
# 64      903S05  1.00000    903      S05
# 65      905903  1.00000    905      903
# 66      908777  1.00000    908      777
# 67      939140  1.00000    939      140
# 68      941700  1.00000    941      700
# 69      979860  1.00000    979      860
# 70      980220  1.00000    980      220
# 71      980443  1.00000    980      443
# 72      981540  1.00000    981      540
# 73      981661  1.00000    981      661
# 74      982314  1.00000    982      314
# 75      982427  1.00000    982      427
# 76      BR1016  1.00000    BR1      016
# 77      NL1265  1.00000    NL1      265
# 78      NL3004  1.00000    NL3      004
# 79      PL1403  1.00000    PL1      403
# 80      SE6142  1.00000    SE6      142
# 81  US40144009  1.00000    US4  0144009

# %%
from datetime import datetime

# %%
if datetime.now().month < 10:
    month_year = str(datetime.now().year)+"0"+str(datetime.now().month)
else:
    month_year = str(datetime.now().year)+str(datetime.now().month)

month_year
# Out:
# '202005'

# %%
final_df = pd.DataFrame()

# %%
final_df["x"] = df1["counts"]

# %%
final_df["A"] = "XX"
final_df["B"] = month_year

final_df["c"] = ""
final_df["d"] = ""
final_df["e"] = ""

final_df["f"] = "A000"
final_df["g"] = "420"
final_df["h"] = "068"

final_df["i"] = df1["RecCC1"]
final_df["j"] = df1["RecCC2"]
final_df["k"] = df1["counts"]
del final_df['x']

# %%
final_df
# Out:
#      A       B c d e     f    g    h    i        j        k
# 0   XX  202005        A000  420  068  047      561  1.00000
# 1   XX  202005        A000  420  068  05D      016  1.00000
# 2   XX  202005        A000  420  068  060      874  1.00000
# 3   XX  202005        A000  420  068  062      545  1.00000
# 4   XX  202005        A000  420  068  13C      900  9.00000
# 5   XX  202005        A000  420  068  154      570  3.00000
# 6   XX  202005        A000  420  068  154      786  1.00000
# 7   XX  202005        A000  420  068  170      998  1.00000
# 8   XX  202005        A000  420  068  183      200  2.00000
# 9   XX  202005        A000  420  068  18C      955  1.00000
# 10  XX  202005        A000  420  068  201      567  2.00000
# 11  XX  202005        A000  420  068  201      894  1.00000
# 12  XX  202005        A000  420  068  209      529  6.00000
# 13  XX  202005        A000  420  068  211      512  3.00000
# 14  XX  202005        A000  420  068  211      588  1.00000
# 15  XX  202005        A000  420  068  211      919  1.00000
# 16  XX  202005        A000  420  068  213      690  1.00000
# 17  XX  202005        A000  420  068  251      151  1.00000
# 18  XX  202005        A000  420  068  257      720  1.00000
# 19  XX  202005        A000  420  068  280      773  1.00000
# 20  XX  202005        A000  420  068  287      420  1.00000
# 21  XX  202005        A000  420  068  287      601  2.00000
# 22  XX  202005        A000  420  068  287      704  8.00000
# 23  XX  202005        A000  420  068  287      922  1.00000
# 24  XX  202005        A000  420  068  295      160  1.00000
# 25  XX  202005        A000  420  068  372      307  1.00000
# 26  XX  202005        A000  420  068  372      311  1.00000
# 27  XX  202005        A000  420  068  375      255  1.00000
# 28  XX  202005        A000  420  068  38F      062  1.00000
# 29  XX  202005        A000  420  068  506      803  1.00000
# 30  XX  202005        A000  420  068  506      875  1.00000
# 31  XX  202005        A000  420  068  511      451  1.00000
# 32  XX  202005        A000  420  068  515      650  1.00000
# 33  XX  202005        A000  420  068  527      920  1.00000
# 34  XX  202005        A000  420  068  537      120  1.00000
# 35  XX  202005        A000  420  068  54F      841  1.00000
# 36  XX  202005        A000  420  068  54F      847  3.00000
# 37  XX  202005        A000  420  068  564      240  1.00000
# 38  XX  202005        A000  420  068  586      383  1.00000
# 39  XX  202005        A000  420  068  61B      226  1.00000
# 40  XX  202005        A000  420  068  652      050  2.00000
# 41  XX  202005        A000  420  068  652      S41  1.00000
# 42  XX  202005        A000  420  068  652      W41  1.00000
# 43  XX  202005        A000  420  068  667      270  1.00000
# 44  XX  202005        A000  420  068  667      906  1.00000
# 45  XX  202005        A000  420  068  67C      701  1.00000
# 46  XX  202005        A000  420  068  684      031  1.00000
# 47  XX  202005        A000  420  068  684      159  1.00000
# 48  XX  202005        A000  420  068  698      250  1.00000
# 49  XX  202005        A000  420  068  698      272  2.00000
# 50  XX  202005        A000  420  068  698      301  1.00000
# 51  XX  202005        A000  420  068  698      307  3.00000
# 52  XX  202005        A000  420  068  698      396  1.00000
# 53  XX  202005        A000  420  068  711      399  3.00000
# 54  XX  202005        A000  420  068  718      940  1.00000
# 55  XX  202005        A000  420  068  815      192  1.00000
# 56  XX  202005        A000  420  068  815      888  1.00000
# 57  XX  202005        A000  420  068  816      830  1.00000
# 58  XX  202005        A000  420  068  829      510  1.00000
# 59  XX  202005        A000  420  068  829      620  1.00000
# 60  XX  202005        A000  420  068  865      910  1.00000
# 61  XX  202005        A000  420  068  866      958  1.00000
# 62  XX  202005        A000  420  068  903      S03  3.00000
# 63  XX  202005        A000  420  068  903      S04  1.00000
# 64  XX  202005        A000  420  068  903      S05  1.00000
# 65  XX  202005        A000  420  068  905      903  1.00000
# 66  XX  202005        A000  420  068  908      777  1.00000
# 67  XX  202005        A000  420  068  939      140  1.00000
# 68  XX  202005        A000  420  068  941      700  1.00000
# 69  XX  202005        A000  420  068  979      860  1.00000
# 70  XX  202005        A000  420  068  980      220  1.00000
# 71  XX  202005        A000  420  068  980      443  1.00000
# 72  XX  202005        A000  420  068  981      540  1.00000
# 73  XX  202005        A000  420  068  981      661  1.00000
# 74  XX  202005        A000  420  068  982      314  1.00000
# 75  XX  202005        A000  420  068  982      427  1.00000
# 76  XX  202005        A000  420  068  BR1      016  1.00000
# 77  XX  202005        A000  420  068  NL1      265  1.00000
# 78  XX  202005        A000  420  068  NL3      004  1.00000
# 79  XX  202005        A000  420  068  PL1      403  1.00000
# 80  XX  202005        A000  420  068  SE6      142  1.00000
# 81  XX  202005        A000  420  068  US4  0144009  1.00000

# %%
final_df.to_excel("output.xlsx", header=False, index = False)
